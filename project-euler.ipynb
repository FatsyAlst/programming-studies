# %% [markdown]
# Mathematical and Computational/Programming problems from [Project Euler](https://projecteuler.net/about)

# %%
# Problem 0

# Among the first 510 thousand square numbers, what is the sum of all the odd squares?

sum = 0
for n in range(510001):
    if n % 2 == 1:
        sum += n ** 2

print(sum)
# Out:
# 22108499999915000

# %% [markdown]
# ![image.png](attachment:image.png)
